# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from numpy import log, array



dx_vals = array([0.01, 0.0105, 0.0111, 0.0118, 0.0125, 0.0133,
          0.0143, 0.0154, 0.0167, 0.0182, 0.02, 0.0222,
          0.025, 0.0286, 0.0333])#, 0.4] # List to store dx
max_err_dev = array([0.0017226808983763174, 0.0018290182019656605,
              0.001934468034019537, 0.0020840430763745337,
              0.0022458484909437955, 0.0024448594843506804,
              0.0027323337782837517, 0.0032572099906162232,
              0.004189316125622173, 0.005798734218786633,
              0.006043924158525083, 0.0074202764221448225,
              0.008496025994704651, 0.010263805776869507,
              0.011190095202630387])#, 0.014678290952583568] # Lists to store mean(abs(u_numerical - u_analytic))
max_err_opt = array([0.0014927344089295314, 0.0015923028595872628,
              0.0017429914924031809, 0.002006318392721633,
              0.002472757085043253, 0.003212310155456301,
              0.004191609072763517, 0.005163504580995524,
              0.005790970169789508, 0.0058245939763328855,
              0.005848776515164901, 0.00668593094464999,
              0.007146874291660912, 0.008982823354992252,
              0.009571299754139773])#, 0.011997922078787472]
    
fig = plt.figure()
plt.plot(dx_vals, 1000.*max_err_dev, 'k-', linewidth=0.75, label='Conventional 6th order')
plt.plot(dx_vals, 1000.*max_err_opt, 'r-', linewidth=0.75, label='Optimized 4th order')
plt.title("Percentage mean error at t = 40s vs grid spacing\n Courant number = 0.2")
plt.legend(loc='best')
plt.xlabel("Δx")
plt.ylabel("Percentage mean error")
plt.savefig("Figures/Max_Absolute_Error/error_plot.png", dpi=200)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
